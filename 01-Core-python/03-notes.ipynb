# %% [markdown]
# # FUNCTIONS

# %%
n=4
s="devops_commuity"
for i in range(n): # 0,1,2,3
    print(s)
# Out:
# devops_commuity
# devops_commuity
# devops_commuity
# devops_commuity

# %%
n=4
s="mounicas"
for i in range(n): # 0,1,2,3
    print(s)
# Out:
# mounicas
# mounicas
# mounicas
# mounicas

# %%
n=10
s="Rahuls"
for i in range(n): # 0,1,2,3
    print(s)
# Out:
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls

# %%
n=4
s="devops_commuity"
for i in range(n): # 0,1,2,3
    print(s)
n=10
s="Rahuls"
for i in range(n): # 0,1,2,3
    print(s)
n=4
s="mounicas"
for i in range(n): # 0,1,2,3
    print(s)
# Out:
# devops_commuity
# devops_commuity
# devops_commuity
# devops_commuity
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# mounicas
# mounicas
# mounicas
# mounicas

# %%
n=4
s="devops_commuity"
for i in range(n): # 0,1,2,3
    print(s)
n=10
s="Rahuls"
for i in range(n): # 0,1,2,3
    print(s)
n=4
s="mounicas"
for i in range(n): # 0,1,2,3
    print(s)
n=3
s="Manoj"
for i in range(n):
    print(s)
# Out:
# devops_commuity
# devops_commuity
# devops_commuity
# devops_commuity
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# Rahuls
# mounicas
# mounicas
# mounicas
# mounicas
# Manoj
# Manoj
# Manoj

# %%
def fun():
    print("devops_community")

# %%
fun()
# Out:
# devops_community

# %%
def rocky_bhai():
    print("voilance...")

# %%
rocky_bhai()
# Out:
# voilance...

# %%
def rocky_bhai():
    for i in range(5):
        print("voilance...")

# %%
rocky_bhai()
# Out:
# voilance...
# voilance...
# voilance...
# voilance...
# voilance...

# %%
def rocky_bhai(n):
    for i in range(n):
        print("voilance...")

# %%
rocky_bhai()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 rocky_bhai()
#
# TypeError: rocky_bhai() missing 1 required positional argument: 'n'

# %%
rocky_bhai(1)
# Out:
# voilance...

# %%
rocky_bhai(10)
# Out:
# voilance...
# voilance...
# voilance...
# voilance...
# voilance...
# voilance...
# voilance...
# voilance...
# voilance...
# voilance...

# %%
def rocky_bhai(n):
    for i in range(n):
        print("voilance...")

print("Danger....")
# Out:
# Danger....

# %%
rocky_bhai(5)
# Out:
# voilance...
# voilance...
# voilance...
# voilance...
# voilance...

# %%
def rocky_bhai(n):
    for i in range(n):
        print("voilance...")

print("Danger....")
rocky_bhai(5)
# Out:
# Danger....
# voilance...
# voilance...
# voilance...
# voilance...
# voilance...

# %%
def rocky_bhai(n):
    for i in range(n):
        print("voilance...")

print("Danger....")
rocky_bhai(5)
print("Adheera your dead...")
rocky_bhai(4)
# Out:
# Danger....
# voilance...
# voilance...
# voilance...
# voilance...
# voilance...
# Adheera your dead...
# voilance...
# voilance...
# voilance...
# voilance...

# %%
def rocky_bhai(n,s):
    for i in range(n):
        print("voilance...")
        print(f"{s}... you are dead")

# %%
rocky_bhai()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 rocky_bhai()
#
# TypeError: rocky_bhai() missing 2 required positional arguments: 'n' and 's'

# %%
rocky_bhai(5,"adheer")
# Out:
# voilance...
# adheer... you are dead
# voilance...
# adheer... you are dead
# voilance...
# adheer... you are dead
# voilance...
# adheer... you are dead
# voilance...
# adheer... you are dead

# %%
rocky_bhai(5,"adheer")
rocky_bhai(1,"Manoj")
rocky_bhai(2,"Devops")
rocky_bhai(5,"python")
# Out:
# voilance...
# adheer... you are dead
# voilance...
# adheer... you are dead
# voilance...
# adheer... you are dead
# voilance...
# adheer... you are dead
# voilance...
# adheer... you are dead
# voilance...
# Manoj... you are dead
# voilance...
# Devops... you are dead
# voilance...
# Devops... you are dead
# voilance...
# python... you are dead
# voilance...
# python... you are dead
# voilance...
# python... you are dead
# voilance...
# python... you are dead
# voilance...
# python... you are dead

# %%
print(rocky_bhai(1,"adheer"))
# Out:
# voilance...
# adheer... you are dead
# None

# %%
def rocky_bhai(n,s):
    for i in range(n):
        print(f"voilance... {s}")
    return 8

rocky_bhai(1,"i dont know")
# Out:
# voilance... i dont know
# 8

# %%
print(rocky_bhai(1,"i dont know"))
# Out:
# voilance... i dont know
# 8

# %%
def fun():
    return 8

print(fun)
# Out:
# <function fun at 0x111c25d00>

# %%
def fun():
    return 8

test=fun()
print(test)
# Out:
# 8

# %%
# Out:
# <function fun at 0x111c5b100>

# %%
# def add(a,b):
#     print(a+b)

# x=add(10,20)
# print(x)
# print(x+10)


def add(a,b):
    return a+b

x=add(10,20)
print(x)
print(x+10)

# %%
def table(n):
    for i in range(1,11):
        print(f"{n} X {i} = {n*i}")

# %%
table(5)
# Out:
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %%
table(10)
# Out:
# 10 X 1 = 10
# 10 X 2 = 20
# 10 X 3 = 30
# 10 X 4 = 40
# 10 X 5 = 50
# 10 X 6 = 60
# 10 X 7 = 70
# 10 X 8 = 80
# 10 X 9 = 90
# 10 X 10 = 100

# %%
def even_or_odd(num):
    if num%2==0:
        print("the number is even")
    else:
        print("number is odd..")

# %%
even_or_odd(100)
# Out:
# the number is even

# %%
even_or_odd(23)
# Out:
# number is odd..

# %% [markdown]
# # MODULES

# %%
num=16
result= num**0.5
print(result)
# Out:
# 4.0

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
print(math.sqrt(25))
# Out:
# 5.0

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
data = {
    "Name": ["Manoj","Zara","Mounica","Rahul","sai"],
    "Age": [30,20,25,22,23],
    "City": ["Banglore","Ranchi","US","Mumbai","Hyd"]
}

# %%
print(data)
# Out:
# {'Name': ['Manoj', 'Zara', 'Mounica', 'Rahul', 'sai'], 'Age': [30, 20, 25, 22, 23], 'City': ['Banglore', 'Ranchi', 'US', 'Mumbai', 'Hyd']}

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (91 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl (10.7 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 4.3 MB/s eta 0:00:00a 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

data = {
    "Name": ["Manoj","Zara","Mounica","Rahul","sai"],
    "Age": [30,20,25,22,23],
    "City": ["Banglore","Ranchi","US","Mumbai","Hyd"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age      City
# 0    Manoj   30  Banglore
# 1     Zara   20    Ranchi
# 2  Mounica   25        US
# 3    Rahul   22    Mumbai
# 4      sai   23       Hyd

# %%
servers=["server-1","server-2","server-3"]
cpu_usage=[45,80,60]

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/fd/14/baad3222f424b19ce6ad243c71de1ad9ec6b2e4eb1e458a48fdc6d120401/matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (52 kB)
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/0d/44/c4b0b6095fef4dc9c420e041799591e3b63e9619e3044f7f4f6c21c0ab24/contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.5 kB)
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...

# %%
import matplotlib.pyplot as plt

servers=["server-1","server-2","server-3"]
cpu_usage=[45,80,60]

plt.bar(servers,cpu_usage)

plt.show()

# %%
import matplotlib.pyplot as plt

servers=["server-1","server-2","server-3"]
cpu_usage=[45,80,60]

plt.bar(servers,cpu_usage)
plt.xlabel("servers")
plt.ylabel("Cpu usage")
plt.title("Server CPu usage")

plt.show()
